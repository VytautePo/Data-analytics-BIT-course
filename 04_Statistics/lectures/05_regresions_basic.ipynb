# %%
import pandas as pd
import seaborn as sns

# %%
insurance = pd.read_csv(r"C:\Users\linke\Desktop\Python\Python data files\insurance.csv")

# %%
insurance.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
sns.boxenplot(x=insurance["charges"])
# Out:
# <Axes: xlabel='charges'>

# %%
import numpy as np
import seaborn as sns

xx = np.array([-0.51, 51.2])
yy = np.array([0.33, 51.6])
means = [xx.mean(), yy.mean()]  
stds = [xx.std() / 3, yy.std() / 3]
corr = 1   # correlation KEISTI
covs = [
    [stds[0]**2, stds[0]*stds[1]*corr],
    [stds[0]*stds[1]*corr, stds[1]**2]
]
 
m = np.random.multivariate_normal(means, covs, 1000).T
 
import pandas as pd
 
df = pd.DataFrame(m).T
df.columns = ["X", "Y"]
df.head()
 
sns.scatterplot(df, x="X", y="Y")
 
sns.despine()

# %%
sns.lmplot(insurance, x="bmi", y="charges")
 
sns.lmplot(insurance, x="bmi", y="charges", hue="smoker")

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')
