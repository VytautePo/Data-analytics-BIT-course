# %% [markdown]
# Tasks with datetime, try/except/finally, boolean

# %% [markdown]
# tasks with datetime

# %% [markdown]
# 1. Create today’s date using datetime.date.today() and print it.

# %%
import datetime
